# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 4 * y
deq2 = diff(y,t) == x + y
syst = [deq1, deq2]
sol_syst = desolve_system(syst, [x,y])
show(sol_syst)
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == 2 * x - y
deq2 = diff(y,t) == x + 2 * y
syst = [deq1, deq2]
sol_syst = desolve_system(syst, [x,y])
show(sol_syst)
# Out:
# [x(t) == (cos(t)*x(0) - sin(t)*y(0))*e^(2*t),
#  y(t) == (sin(t)*x(0) + cos(t)*y(0))*e^(2*t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == x - y + z
deq2 = diff(y,t) == x + y - z
deq3 = diff(z,t) == -y + 2 * z
syst = [deq1, deq2, deq3]
sol_syst = desolve_system(syst, [x,y,z])
show(sol_syst)
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (2*x(0) + y(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + e^t*y(0),
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (x(0) + y(0) - z(0))*e^t]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == 5 * x + 3 * y + 1
deq2 = diff(y,t) == (-6) * x - 4 * y + e^(-t)
syst = [deq1, deq2]
sol_syst = desolve_system(syst, [x,y])
show(sol_syst)
# Out:
# [x(t) == 1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) - t*e^(-t) - 1/3*(3*x(0) + 3*y(0) - 2)*e^(-t) - 2,
#  y(t) == -1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) + 2*t*e^(-t) + 1/3*(6*x(0) + 6*y(0) - 5)*e^(-t) + 3]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 3 * y + cos(t)
deq2 = diff(y,t) == x - y + 2 * t
syst = [deq1, deq2]
sol_syst = desolve_system(syst, [x,y])
show(sol_syst)
# Out:
# [x(t) == 3/40*(10*x(0) + 10*y(0) + 9)*e^(2*t) + 1/40*(10*x(0) - 30*y(0) - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*x(0) + 10*y(0) + 9)*e^(2*t) - 1/40*(10*x(0) - 30*y(0) - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == x - 2 * y - 2 * z + e^(-t)
deq2 = diff(y,t) == (-2) * x + y + 2 * z
deq3 = diff(z,t) == 2 * x - y - 3 * z + e^(-t)
syst = [deq1, deq2, deq3]
sol_syst = desolve_system(syst, [x,y,z])
show(sol_syst)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t) - cosh(sqrt(3)*t)*y(0),
#  y(t) == -1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + cosh(sqrt(3)*t)*y(0),
#  z(t) == sqrt(3)*(x(0) - z(0))*sinh(sqrt(3)*t) - (x(0) + y(0) - z(0))*cosh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t)]

# %%
#2
#a
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 4*y
deq2 = diff(y,t) == x+y
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,1,2]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
g1=plot(sol_x(t),t,-10,10, color='magenta')
g2=plot(sol_y(t),t,-10,10, color='green')
show(g1+g2)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]
# Graphics object consisting of 2 graphics primitives

# %%
#b
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x - y + t -1
deq2 = diff(y,t) == (-2) * x + 4 * y + cos(t)
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,0,1]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
g1=plot(sol_x(t),t,-10,10, color='magenta')
g2=plot(sol_y(t),t,-10,10, color='green')
show(g1+g2)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]
# Graphics object consisting of 2 graphics primitives

# %%
#c
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 2 * y + e^(-t)
deq2 = diff(y,t) == (-2) * x + y + 1
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,0,1]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
g1=plot(sol_x(t),t,-10,10, color='cyan')
g2=plot(sol_y(t),t,-10,10, color='purple')
show(g1+g2)
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]
# Graphics object consisting of 2 graphics primitives

# %%
#d
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == -x + 3 * y + 3 * z + 27 * t^2
deq2 = diff(y,t) == 2 * x - 2 * y - 5 * z + 3 * t
deq3 = diff(z,t) == (-2) * x + 3 * y + 6 * z + 3
syst = [deq1, deq2, deq3]
vars=[x,y,z]
in_cond=[0,50,-30,26]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
sol_z(t) = sol[2].rhs()
g1=plot(sol_x(t),t,5,15, color='cyan')
g2=plot(sol_y(t),t,5,15, color='purple')
g3=plot(sol_z(t),t,5,15, color='magenta')
show(g1+g2+g3)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]
# Graphics object consisting of 3 graphics primitives

# %%
#3 a b c 1
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + y
deq2 = diff(y,t) == (-2) * x + 4 * y
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,3,0]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
show(sol_x, sol_y)
l1 = limit(sol_x(t), t=infinity,dir='plus')
l2 = limit(sol_y(t), t=infinity,dir='plus')
show(l1,l2)
f1(u,v) = u + v
f2(u,v) = (-2)*u + 4*v
n = sqrt(f1(u,v) ^2+f2(u,v)^2)
g1 = plot_vector_field([f1(u,v),f2(u,v)],[u,-10,10], [v,-10,10], color = 'magenta')
g2 = parametric_plot((sol_x(t), sol_y(t)), (t,-10,10), color = 'purple')
g = g1 + g2
g.show(xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]
# t |--> -3*e^(3*t) + 6*e^(2*t) t |--> -6*e^(3*t) + 6*e^(2*t)
# -Infinity -Infinity
# Graphics object consisting of 2 graphics primitives

# %%
#3 a b c 2
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + y
deq2 = diff(y,t) == (-2) * x + 4 * y
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,0,3]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
show(sol_x, sol_y)
l1 = limit(sol_x(t), t=infinity,dir='plus')
l2 = limit(sol_y(t), t=infinity,dir='plus')
show(l1,l2)
f1(u,v) = u + v
f2(u,v) = (-2)*u + 4*v
n = sqrt(f1(u,v) ^2+f2(u,v)^2)
g1 = plot_vector_field([f1(u,v),f2(u,v)],[u,-5,5], [v,-5,5], color = 'magenta')
g2 = parametric_plot((sol_x(t), sol_y(t)), (t,-10,10), color = 'purple')
g = g1 + g2
g.show(xmin = -5, xmax = 5, ymin = -5, ymax = 5)
# Out:
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]
# t |--> 3*e^(3*t) - 3*e^(2*t) t |--> 6*e^(3*t) - 3*e^(2*t)
# +Infinity +Infinity
# Graphics object consisting of 2 graphics primitives

# %%
#3 a b c 3
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + y
deq2 = diff(y,t) == (-2) * x + 4 * y
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,-3,0]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
show(sol_x, sol_y)
l1 = limit(sol_x(t), t=infinity,dir='plus')
l2 = limit(sol_y(t), t=infinity,dir='plus')
show(l1,l2)
f1(u,v) = u + v
f2(u,v) = (-2)*u + 4*v
n = sqrt(f1(u,v) ^2+f2(u,v)^2)
g1 = plot_vector_field([f1(u,v),f2(u,v)],[u,-5,5], [v,-5,5], color = 'magenta')
g2 = parametric_plot((sol_x(t), sol_y(t)), (t,-10,10), color = 'purple')
g = g1 + g2
g.show(xmin = -5, xmax = 5, ymin = -5, ymax = 5)
# Out:
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]
# t |--> 3*e^(3*t) - 6*e^(2*t) t |--> 6*e^(3*t) - 6*e^(2*t)
# +Infinity +Infinity
# Graphics object consisting of 2 graphics primitives

# %%
#3 a b c 4
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + y
deq2 = diff(y,t) == (-2) * x + 4 * y
syst = [deq1, deq2]
vars=[x,y]
in_cond=[0,0,-3]
sol = desolve_system(syst, vars, in_cond)
show(sol)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
show(sol_x, sol_y)
l1 = limit(sol_x(t), t=infinity,dir='plus')
l2 = limit(sol_y(t), t=infinity,dir='plus')
show(l1,l2)
f1(u,v) = u + v
f2(u,v) = (-2)*u + 4*v
n = sqrt(f1(u,v) ^2+f2(u,v)^2)
g1 = plot_vector_field([f1(u,v),f2(u,v)],[u,-5,5], [v,-5,5], color = 'magenta')
g2 = parametric_plot((sol_x(t), sol_y(t)), (t,-10,10), color = 'purple')
g = g1 + g2
g.show(xmin = -5, xmax = 5, ymin = -5, ymax = 5)
# Out:
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]
# t |--> -3*e^(3*t) + 3*e^(2*t) t |--> -6*e^(3*t) + 3*e^(2*t)
# -Infinity -Infinity
# Graphics object consisting of 2 graphics primitives

# %%
#4
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) ==  y
deq2 = diff(y,t) == (-1) * x - 2 * y
syst = [deq1, deq2]
vars = [x,y]
sol = desolve_system(syst, vars)
sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
show(sol)
l1 = limit(sol_x(t), t=infinity,dir='plus')
l2 = limit(sol_y(t), t=infinity,dir='plus')
show(l1,l2)

f1(u,v) = v
f2(u,v) = (-1)*u - 2*v
g1 = plot_vector_field([f1(u,v),f2(u,v)],[u,-5,5], [v,-5,5], color = 'lime')
show(g1)
# Out:
# [x(t) == t*e^(-t)*x(0) - 3*t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) + 3*t*e^(-t) - 3*e^(-t)]
# 0 '\n' 0
# Graphics object consisting of 1 graphics primitive
