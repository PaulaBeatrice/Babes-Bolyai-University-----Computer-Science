# %% [markdown]
# # Laborator 1: Introducere in SageMath

# %% [markdown]
# ## Calcule in SageMath

# %% [markdown]
# ### Operatii algebrice de baza

# %% [raw]
# “cele patru operatii”     a+b, a-b, a*b, a/b
#
# ridicarea la putere       a^b sau a**b
#
# radical                   sqrt(a)
#
# radical de ordin n        a^(1/n)

# %% [markdown]
# In notebook, se pot introduce comenzi in linia de comanda, rezultatul obtinandu-se apasand butonul Run sau folosind combinatia de taste Shift+Enter
#
# Combinatia de taste Alt+Enter executa comanda si insereaza o noua linie de comanda.

# %%
1+2-3
# Out:
# 0

# %%
2*3/7+3^2
# Out:
# 69/7

# %%
(1 + 2*(3 + 5^2))*sqrt(9)
# Out:
# 171

# %% [markdown]
# Pentru a obtine valoarea aproximativa a unui numar, se va scrie acel numar urmat de simbolul "." (punctul decimal)

# %%
15/6
# Out:
# 5/2

# %%
15./6
# Out:
# 2.50000000000000

# %% [markdown]
# De asemenea, functia *numerical_approx* returneaza valoarea aproximativa a unei expresii numerice

# %%
numerical_approx(15/6)
# Out:
# 2.50000000000000

# %%
 numerical_approx(44/13, digits=60)
# Out:
# 3.38461538461538461538461538461538461538461538461538461538462

# %% [markdown]
# ### Alte operatii cu numere intregi

# %% [raw]
# catul impartirii                   a // b
#
# restul impartirii                  a % b
#
# catul si restul                    divmod(a,b)
#
# n!                                 factorial(n)
#
# coeficient binomial                binomial(n,k)

# %% [markdown]
# ### Functii matematice uzuale

# %% [raw]
# parte intreaga                    floor(a)
#
# modulul                           abs(a)
#
# exponentiala si logaritmul        exp, log
#
# Logaritm in baza a                log(x, a)
#
# Functii trigonometrice            sin, cos, tan
#
# Functii trigonometrice inverse    arcsin, arccos, arctan
#
# Functii hiperbolice               sinh, cosh, tanh
#
# Functii hiperbolic inverse        arcsinh, arccosh, arctanh
#
# Partea intreaga, etc              floor, ceil, trunc, round
#
# Radical de ordin 2 si n           sqrt, nth_root

# %% [markdown]
# ## Variabile

# %% [markdown]
# Variabilele trebuie declarate explicit inainte de a fi utilizate. (SR este abrevierea de la Symbolic Ring):

# %%
x = SR.var('x')
p1=(x+1)^2
p1
# Out:
# (x + 1)^2

# %% [markdown]
# Pentru a dezvolta expresia se foloseste comanda *variable.expand()*

# %%
p1.expand()
# Out:
# x^2 + 2*x + 1

# %%
p2=x^2 + 2*x + 1
p2
# Out:
# x^2 + 2*x + 1

# %% [markdown]
# Pentru a descompune in factori o expresie data se foloseste comanda *variabila.factor()*

# %%
p2.factor()
# Out:
# (x + 1)^2

# %%
p3=x^2-5*x + 6
p3.factor()
# Out:
# (x - 2)*(x - 3)

# %% [markdown]
# Comanda *vaiabila.subs()* se foloseste pentru a calcula valoarea unei expresii pentru o anumita valoare a parametrilor sai.

# %%
p1.subs(x=-1)
# Out:
# 0

# %%
p3.subs(x=2)
# Out:
# 0

# %%
p3.subs(x=-3)
# Out:
# 30

# %% [markdown]
# Comanda *var(’x’)* se poate folosi in locul comenzii *x = SR.var(’x’)*

# %%
x=var('x')
p=(2*x-1)^3
p.expand()
# Out:
# 8*x^3 - 12*x^2 + 6*x - 1

# %%
x,y=var('x,y')
p=(2*x+y)^2
p.expand()
# Out:
# 4*x^2 + 4*x*y + y^2

# %%
p.subs(x=1,y=1)
# Out:
# 9

# %% [markdown]
# ## Ecuatii si sisteme de ecuatii algebrice

# %% [markdown]
# O ecuatie se defineste folosind semnul "==", ex. *f(x)==g(x)*.
#
# Cele mai folosite comenzi pentru rezolvarea ecuatiilor sunt:

# %% [raw]
# Solutie simbolica                       solve
#
# Radacini (cu ordin de multiplicitate)   roots
#
# Solutie numerica                        find_root

# %%
x=var('x')
eq1=x^2+x+1==0
solve(eq1,x)
# Out:
# [x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %% [markdown]
# Nu toate ecuatiile pot fi rezolvate cu ajutorul softului SageMath, in exemplul urmator SageMath nu returneaza nicio solutie.

# %%
eq2=exp(-x)==x
solve(eq2,x)
# Out:
# [x == e^(-x)]

# %% [markdown]
# Pentru a determina o solutie numerica se foloseste *find_root(equation,a,b)*, comanda ce va determina solutia in intervalul *[a,b]*

# %%
find_root(eq2,0,2)
# Out:
# 0.5671432904098384

# %% [markdown]
# Comanda *solve* poate fi folosita si pentru sisteme de ecuatii, acestea putand fi definite in Sage folosind [ ]
#
# *[eq1,eq2,...,eqn]*.

# %%
x,y=var('x,y')
syst=[x+2*y==1,x-y==3]
solve(syst,x,y)
# Out:
# [[x == (7/3), y == (-2/3)]]

# %% [markdown]
# ## Limite

# %% [markdown]
# Pentru a calcula o limita se va folosi comanda *limit*

# %%
n,x=var('n,x')

# %%
limit(1/n,n=infinity)
# Out:
# 0

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
limit(1/x, x=0)
# Out:
# Infinity

# %% [markdown]
# Ultimul rezultat se refera la faptul ca una dintre limite, la stanga sau la dreapta, este infinita.
# Pentru a calcula limita la stanga (minus) sau la dreapta (plus) se poate folosi optiunea *dir*.

# %%
limit(1/x, x=0,dir='minus')
# Out:
# -Infinity

# %%
limit(1/x, x=0,dir='plus')
# Out:
# +Infinity

# %% [markdown]
# **Functii folositoare la analiza:**

# %% [raw]
#        Derivata                   diff(f(x), x)
#
#        Derivata de ordin n        diff(f(x), x, n)
#
#        Primitiva                  integrate(f(x), x)
#
#        Integrala definita         integral_numerical(f(x), a, b)
#
#        Suma                       sum(f(i), i, imin, imax)
#
#        Limita                     limit(f(x), x=a)
#
#        Serie Taylor               taylor(f(x), x, a, n)
#
#        Serie de puteri            f.series(x==a, n)

# %% [markdown]
# ## Derivarea functiilor

# %%
f(x)=exp(x^2)+3

# %%
diff(f(x),x,2)
# Out:
# 4*x^2*e^(x^2) + 2*e^(x^2)

# %%
diff(f(x),x,3)
# Out:
# 8*x^3*e^(x^2) + 12*x*e^(x^2)

# %% [markdown]
# ## Integrarea functiilor

# %%
x=var('x')

# %%
integrate(cos(x),x)
# Out:
# sin(x)

# %%
f(x)=exp(x)*cos(x)
integrate(f(x),x)
# Out:
# 1/2*(cos(x) + sin(x))*e^x

# %% [markdown]
# Pentru integrale definita se foloseste *integrate(f(x),x,a,b)*

# %%
integrate(cos(x),x,0,pi/2)
# Out:
# 1

# %% [markdown]
# Sage nu poate calcula intotdeauna valoarea integralei definite

# %%
integrate(sin(sqrt(1 - x^3)), x, 0,1)
# Out:
# integrate(sin(sqrt(-x^3 + 1)), x, 0, 1)

# %% [markdown]
# Pentru a determina valoarea numerica a unei intergrale definite pe un interval se foloseste functia  *integral_numerical*, care returneaza o pereche, in care prima valoare este valoarea aproximativa integralei, iar a doua pereche este eroarea estimarii.

# %%
integral_numerical(sin(sqrt(1 - x^3)), 0, 1)
# Out:
# (0.7315380084233594, 3.953379981670976e-07)

# %% [markdown]
# ## Grafice 2D

# %% [markdown]
# ### Reprezentarea grafica a functiilor

# %% [markdown]
# Pentru a reprezenta grafic functia $f(x)$ pe intervalul $[a, b]$, se foloseste comanda *plot(f(x), a, b)* sau sintaxa alternativa *plot(f(x), x, a, b)*.

# %%
f(x)=sin(x)/x
plot(f(x),-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Comanda plot are mai multe optiuni. Cele mai importante sunt:

# %% [raw]
# plot_points (default value 200): numarul minim de puncte calculate;
#
# xmin and xmax: capetele intervalului de reprezentare a functiei;
#
# color: culoarea graficului, sau tripletul RGB corespunzator culorii, sau numele culorii cum ar fi ’blue’, sau codul HTML al culorii cum ar fi ’#aaff0b’;
#
# detect_poles (default value False): determina punctele de discontinuitate;
#
# alpha: transparenta culorii liniei;
#
# thickness: grosimea liniei;
#
# linestyle: stilul graficului utilizat cum ar fi grafic prin linie punctata  ’:’, grafic prin linii intrerupte  ’-.’, sau grafic prin linie continua (valoarea implicita) ’-’.

# %% [markdown]
# Se pot reprezenta grafic mai multe functii in aceeasi fereastra, specificand lista functiilor *[f1(x),f2(x),...,fn(x)]* si lista corespunzatoare a culorilor *['color_1','color_2','color_n']*:

# %%
plot([sin(x),f(x)],0,4*pi,color=['red','blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Daca lista de functii este mare, se poate folosi comanda *for* pentru a genera respectiva lista prin indexarea elementelor listei. De exemplu, pentru functia $f_n(x)=\frac{x}{(1+x^2)^n}$ daca dorim sa reprezentam grafic a functiile  $f_1(x)$, ..., $f_{10}(x)$ vom construi prima data lista indexand functiile dupa $n$ si apoi vom reprezenta garficele folosind comanda *plot*:

# %%
x,n=var('x,n')
f(x,n)=x/(1+x^2)^n

# %%
f_list=[f(x,n) for n in [1..10]]
f_list
# Out:
# [x/(x^2 + 1),
#  x/(x^2 + 1)^2,
#  x/(x^2 + 1)^3,
#  x/(x^2 + 1)^4,
#  x/(x^2 + 1)^5,
#  x/(x^2 + 1)^6,
#  x/(x^2 + 1)^7,
#  x/(x^2 + 1)^8,
#  x/(x^2 + 1)^9,
#  x/(x^2 + 1)^10]

# %%
plot(f_list,-3,3)
# Out:
# Graphics object consisting of 10 graphics primitives

# %% [markdown]
# In cazul in care exista puncte de discontinuitate se poate folosi optiunea *detect_poles=True* si putem alege intervalul de marginire a functiei, precizind *ymin* si *ymax* (intervalul pe axa 0y)

# %%
plot(tan(x), -2*pi,2*pi,detect_poles=True,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ### Curbe in forma parametrica

# %% [markdown]
# Daca o curba in forma parametrica este data de
# \begin{equation}
# \left\{
# \begin{array}{rr}
# x\left( t\right)  & =f\left( t\right)  \\
# y\left( t\right)  & =g\left( t\right)
# \end{array}%
# \right. ,\ \ t\in \left[ a,b\right]
# \end{equation}
#
# se va folosi comanda  *parametric_plot((f(t), g(t)), (t, a, b))*.
#
# De exemplu, in cazul semicercului definit de
#
# \begin{equation}
# \left\{
# \begin{array}{rr}
# x\left( t\right)  & =\cos \left( t\right)  \\
# y\left( t\right)  & =\sin \left( t\right)
# \end{array}%
# \right. ,\ \ t\in \left[ -\frac{\pi }{2},\frac{\pi }{2}\right]
# \end{equation}
#
#
# avem:

# %%
t=var('t')
x(t)=cos(t)
y(t)=sin(t)
parametric_plot((x(t), y(t)), (t, -pi/2, pi/2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# Pentru a reprezenta in acelasi sistem de coordonate mai multe curbe date in forma parametrica, vom atribui fiecarui grafic o variabila si le vom combina folosing comanda plus (+), iar pentru afisare comanda *show*.

# %%
g1=parametric_plot((x(t), y(t)), (t, -pi/2, 3*pi/2),color='red')
g2=parametric_plot((2*x(t), y(t)), (t, 0, 2*pi),color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Când lista de curbe date prin ecuatii parametrice este mare, putem folosi comanda *for* pentru a genera lista de curbe si prin adunare le combinam in acelasi grafic, de exemplu, sa reprezentam familia cercurilor centrate in origine $(0,0)$ si de raza $r$
#
# \begin{equation}
# \left\{
# \begin{array}{rr}
# x\left( t\right)  & =r\cdot \cos \left( t\right)  \\
# y\left( t\right)  & =r\cdot \sin \left( t\right)
# \end{array}%
# \right. ,\ \ t\in \left[ 0,2\pi \right]
# \end{equation}
#
# pentru $r=0.1, 0.2, ...,1$

# %%
g=parametric_plot((1/10*cos(t),1/10*sin(t)),(t,0,2*pi))
for k in [2..10]:
    g1=parametric_plot((k/10*cos(t),k/10*sin(t)),(t,0,2*pi))
    g=g+g1
show(g)
# Out:
# Graphics object consisting of 10 graphics primitives

# %% [markdown]
# ### Curbe in forma implicita

# %% [markdown]
# Pentru a reprezenta grafic o curba in forma implicita trebuie folosita comanda
#
# *implicit_plot(f(x, y), (x, a, b), (y, c, d))*

# %%
x,y=var('x,y')
f(x,y)=x^2+y^2
implicit_plot(f(x,y)==1,(x,-1,1),(y,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g1=implicit_plot(f(x,y)==1,(x,-1,1),(y,-1,1))
g2=implicit_plot(f(x,y)==4,(x,-2,2),(y,-2,2))
g3=implicit_plot(f(x,y)==9,(x,-3,3),(y,-3,3))
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives
