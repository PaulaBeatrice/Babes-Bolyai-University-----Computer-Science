# %%
12 + 4 - 5
# Out:
# 11

# %%
2**10
# Out:
# 1024

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
14 + 2 * (5 - 3)
# Out:
# 18

# %%
x = var('x')
eq1 = x**4 - 3/2 * x**3 - x + 3/2 == 0
solve(eq1, x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
x = var('x')
eq2 = sqrt(x**2 + 3*x) == 3
solve(eq2, x)
# Out:
# [x == -3/2*sqrt(5) - 3/2, x == 3/2*sqrt(5) - 3/2]

# %%
x,y = var('x,y')
syst = [2*x + y == 3, x + 3 * y == -1]
solve(syst, x, y)
# Out:
# [[x == 2, y == -1]]

# %%
x,y = var('x,y')
syst = [2 * x + x * y + 2 * y == 59, 3 * x - 2 * x * y + 3 * y == -34]
solve(syst, x, y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
limit(sin(x)/x, x = 0)
# Out:
# 1

# %%
limit((x**3 + 3 * x**2 - 5)/(2 * x**3 - 7 * x), x = infinity )
# Out:
# 1/2

# %%
limit((cos(x) + 1)/(x - pi), x = pi)
# Out:
# 0

# %%
y(x) = 3 * x**3 + 2 * x**2 - 5
diff(y(x),x)
# Out:
# 9*x^2 + 4*x

# %%
y(x) = sqrt(1 - x**4)
diff(y(x), x)
# Out:
# -2*x^3/sqrt(-x^4 + 1)

# %%
y(x) = e**x * sin(x) * cos(x)
diff(y(x), x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
f(x) = 3 * x**3 + 2 * x**2 - 5
integrate(f(x), x, 0, 1)
# Out:
# -43/12

# %%
f(x) = 1 / (x**2)
integrate(f(x), x, 1, infinity)
# Out:
# 1

# %%
f(x) = e**((-1) * x**2)
integrate(f(x), x, -infinity, infinity)
# Out:
# sqrt(pi)

# %%
f(x) = e**(-x) - 1
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x, r = var('x,n')
f(x, r) = 200 * e**(r*x) / (2 * (e**(r*x) - 1) + 100)
r = 0.5
plot(f(x,r), 0, 50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x, r = var('x,n')
f(x, r) = 200 * e**(r*x) / (2 * (e**(r*x) - 1) + 100)
plot(f(x,r).subs(r=-0.5), 0, 50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x) = x * sin(1/x)
plot(f(x), -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x,y,t=var('x,y,t')
x(t) = (1 - cos(t)) * cos(t)
y(t) = (1 - cos(t)) * sin(t)
parametric_plot((x(t),y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x,y,t=var('x,y,t')
x(t) = sin(3*t) * cos(t)
y(t) = sin(3*t) * sin(t)
parametric_plot((x(t),y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x,y,t=var('x,y,t')
x(t) = t - sin(t)
y(t) = 1 - cos(t)
parametric_plot((x(t),y(t)), (t, 0, 6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x,y,t = var('x,y,t')
x(t) = cos(t) + cos(7 * t) / 2 + sin(17 * t) / 3
y(t) = sin(t) + sin(7 * t) / 2 + cos(17 * t) / 3
parametric_plot( (x(t),y(t)) , (t, 0, 2*pi) )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
t,s = var('t,s')
f(t,s) = 1 - (s * cos(4*t) * cos(t)) / (sqrt(1 - s**2 * (cos(4 *t))**2 * (sin(t))**2 ))
s = 0.5
plot(f(t,s), 0, 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
t,s = var('t,s')
f(t,s) = 1 - (s * cos(4*t) * cos(t)) / (sqrt(1 - s**2 * (cos(4 *t))**2 * (sin(t))**2 ))
x(t) = f(t-pi/2, s)
y(t) = f(t,s)

g = parametric_plot( (f(t-pi/2,1) , f(t,1) ) , (t,0,2*pi) )

for k in [2..10]:
    g1 = parametric_plot( ( f(t-pi/2, k) , f(t,k) ) , (t,0,2*pi) )
    g = g + g1
    show(g)
# Out:
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 81 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 7 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 106 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 13 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 114 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 19 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 122 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 25 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 127 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 31 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 129 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 37 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 147 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 47 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 155 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 57 graphics primitives
# verbose 0 (3797: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 161 points.
# verbose 0 (3797: plot.py, generate_plot_points) Last error message: 'Unable to compute f(6.283185307179586)'
# Graphics object consisting of 65 graphics primitives

# %%
x,y = var('x,y')
f(x,y) = x^2 + y^2 - 2*x - 4*y + 4
implicit_plot(f(x,y)==0,(x,-50,50),(y,-50,50))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y) = x^2 - 2*x*y - y^2
implicit_plot(f(x,y)==1,(x,-1,1),(y,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x,y')
f(x,y) = 6*x^2 - 4*x*y + 9*y^2 - 4*x - 32*y - 6
implicit_plot(f(x,y)==0,(x,-50,50),(y,-50,50))
# Out:
# Graphics object consisting of 1 graphics primitive
