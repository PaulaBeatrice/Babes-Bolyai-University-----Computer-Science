# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
eqd
# Out:
# diff(y(x), x) == 2*y(x)

# %%
show(eqd)
# Out:
# diff(y(x), x) == 2*y(x)

# %%
par=desolve(eqd,y)

# %%
show(par)
# Out:
# _C*e^(2*x)

# %%
par
# Out:
# _C*e^(2*x)

# %%
eq1=diff(y,x)==2*x*(1+y^2)
show(eq1)
# Out:
# diff(y(x), x) == 2*(y(x)^2 + 1)*x

# %%
desolve(eq1,y)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
sol1=desolve(eq1,y)

# %%
show(sol1)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
solve(sol1,y)
# Out:
# [y(x) == tan(x^2 + 2*_C)]

# %%
rep=solve(sol1,y)
sol_p=rep[0].rhs()

# %%
_C=var('_C')
sol_p.substitute(_C==1)
# Out:
# tan(x^2 + 2)

# %%
plot(sol_p.substitute(_C==1),x,-2,2,detect_poles='True',ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(sol_p.substitute(_C==3),x,-2,2,detect_poles='True',ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(sol_p.substitute(_C==-2),x,-2,2,detect_poles='True',ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
eq2=(x^2-1)*diff(y,x)+2*x*y^2==0
eq2
# Out:
# 2*x*y(x)^2 + (x^2 - 1)*diff(y(x), x) == 0

# %%
show(eq2)
# Out:
# 2*x*y(x)^2 + (x^2 - 1)*diff(y(x), x) == 0

# %%
sol2=desolve(eq2,y)

# %%
show(sol2)
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
sol21=solve(sol2,y)

# %%
sol_p=sol21[0].rhs()

# %%
show(sol_p)
# Out:
# 1/(2*_C + log(x + 1) + log(x - 1))

# %%
show(sol_p.substitute(_C==3))
# Out:
# 1/(log(x + 1) + log(x - 1) + 6)

# %%
plot(sol_p.substitute(_C==3),x,0,5,detect_poles='True',ymin=0,ymax=0.4)
# Out:
# verbose 0 (3838: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 41 points.
# verbose 0 (3838: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_p.substitute(_C==-3),x,0,10,detect_poles='True',ymin=-0.4,ymax=0)
# Out:
# verbose 0 (3838: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 20 points.
# verbose 0 (3838: plot.py, generate_plot_points) Last error message: 'can't convert complex to float'
# Graphics object consisting of 1 graphics primitive

# %%
eq3=2*x^2*diff(y,x)==x^2+y^2
show(eq3)
# Out:
# 2*x^2*diff(y(x), x) == x^2 + y(x)^2

# %%
sol3=desolve(eq3,y)
sol3
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*y(x) + y(x)^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*y(x))/x)))

# %%
sol31=solve(sol3,y)
sol31
# Out:
# [y(x) == (x*log(-1/sqrt(_C*x)) + x)/log(-1/sqrt(_C*x)), y(x) == (x*log(_C*x) - 2*x)/log(_C*x)]

# %%
sol32=sol31[1].rhs()
show(sol32)
# Out:
# (x*log(_C*x) - 2*x)/log(_C*x)

# %%
show(sol32.substitute(_C==2))
# Out:
# (x*log(2*x) - 2*x)/log(2*x)

# %%
plot(sol32.substitute(_C==2),x,0,10,detect_poles='True',ymin=-60,ymax=30)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sol32.substitute(_C==8),x,0,10,detect_poles='True',ymin=-15,ymax=15)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
eq4=diff(y,x)==(-1)*(x+y)/y
show(eq4)
# Out:
# diff(y(x), x) == -(x + y(x))/y(x)

# %%
sol4=desolve(eq4,y)

# %%
solve(sol4,y)
# Out:
# []

# %%
show(desolve(eq4,y))
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*y(x) + y(x)^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*y(x))/x)))

# %%
yy=var('yy')
sol4.substitute(y==yy)
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*yy + yy^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*yy)/x)))

# %%
f(x,yy,_C)=sol4.substitute(y==yy)
f(x,yy,_C)
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*yy + yy^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*yy)/x)))

# %%
implicit_plot(f(x,yy,0),(x,-10,10),(yy,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq5=diff(y,x,2)+y==sin(x)+cos(x)
eq5
# Out:
# y(x) + diff(y(x), x, x) == cos(x) + sin(x)

# %%
show(eq5)
# Out:
# y(x) + diff(y(x), x, x) == cos(x) + sin(x)

# %%
show(desolve(eq5,y))
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %%
_K1,_K2=var('_K1,_K2')

# %%
sol5=desolve(eq5,y)

# %%
sol5.substitute(_K1==5,_K2==3)
# Out:
# -1/2*(x - 1)*cos(x) + 1/2*x*sin(x) + 3*cos(x) + 5*sin(x)

# %%
plot(sol5.substitute(_K1==5,_K2==3),x,-10,10,detect_poles='True',ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq6=diff(y,x,2)-y==exp(2*x)
show(eq6)
# Out:
# -y(x) + diff(y(x), x, x) == e^(2*x)

# %%
sol6=desolve(eq6,y)

# %%
plot(sol6.substitute(_K1==3,_K2==5),x,-7,7,detect_poles='True',ymin=7,ymax=100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq6=diff(y,x,2)-diff(y,x,1)==1/(1+exp(x))
show(eq6)
# Out:
# -diff(y(x), x) + diff(y(x), x, x) == (1/(e^x + 1))

# %%
sol6=desolve(eq6,y)

# %%
plot(sol6.substitute(_K1==3,_K2==5),-10,10,detect_poles='True',ymin=-5,ymax=100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol6.substitute(_K1==-3,_K2==-5),-10,10,detect_poles='True',ymin=-50,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
_C=var('_C')
_K1,_K2=var('_K1,_K2')
y=function('y')(x)
eq2a=diff(y,x)==1+y^2
show(eq2a)
# Out:
# diff(y(x), x) == y(x)^2 + 1

# %%
sol2a=desolve(eq2a,y)

# %%
sol2a=solve(sol2a,y)

# %%
sol=function('sol')(x)
sol(x)=sol2a[0].rhs()

# %%
sol(x)
# Out:
# tan(_C + x)

# %%
solve(sol(0)==0,_C)
# Out:
# [_C == 0]

# %%
plot(sol(x).substitute(_C==0),x,-3,3,detect_poles='True',ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
eq2b=diff(y,x)==(1/(1-x^2))*y+1+x

# %%
show(eq2b)
# Out:
# diff(y(x), x) == x - y(x)/(x^2 - 1) + 1

# %%
sol(x)=desolve(eq2b,y)

# %%
show(sol)
# Out:
# x |--> 1/2*(sqrt(x^2 - 1)*x + 2*_C - log(2*x + 2*sqrt(x^2 - 1)))*e^(1/2*log(x + 1) - 1/2*log(x - 1))

# %%
const=solve(sol(2)==0,_C)

# %%
show(const)
# Out:
# [_C == -sqrt(3) + 1/2*log(2*sqrt(3) + 4)]

# %%
const1=const[0].rhs()

# %%
const1
# Out:
# -sqrt(3) + 1/2*log(2*sqrt(3) + 4)

# %%
plot(sol(x).substitute(_C==-sqrt(3) + 1/2*log(2*sqrt(3) + 4)),x,0,5,detect_poles='True',ymin=-5,ymax=5)
# Out:
# verbose 0 (3838: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 40 points.
# verbose 0 (3838: plot.py, generate_plot_points) Last error message: 'math domain error'
# Graphics object consisting of 1 graphics primitive

# %%
eq2c=diff(y,x)-2*y==-x^2

# %%
sol(x)=desolve(eq2c,y)

# %%
solve(sol(0)==1/4,_C)
# Out:
# [_C == 0]

# %%
plot(sol(x).substitute(_C==0),x,-7,7,detect_poles='True',ymin=0,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
reset()
x=var('x')
_C=var('_C')
_K1,_K2=var('_K1,_K2')
y=function('y')(x)
eq2d=diff(y,x,2)-5*diff(y,x)+4*y==0

# %%
sol(x)=desolve(eq2d,y)
sol(x)
# Out:
# _K1*e^(4*x) + _K2*e^x

# %%
eq1=sol(0)==5
eq1
# Out:
# _K1 + _K2 == 5

# %%
eq21(x)=diff(sol(x),x)

# %%
eq21(x)
# Out:
# 4*_K1*e^(4*x) + _K2*e^x

# %%
eq2=eq21(0)==8
eq2
# Out:
# 4*_K1 + _K2 == 8

# %%
_K1,_K2=var('_K1,_K2')
syst=[_K1+_K2==5,4*_K1+_K2==8]
solve(syst,_K1,_K2)
# Out:
# [[_K1 == 1, _K2 == 4]]

# %%
plot(sol(x).substitute(_K1==1,_K2==4),x,-10,10,detect_poles='True',ymin=0,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq2e=diff(y,x,2)-4*diff(y,x)+5*y==2*x^2*exp(x)
show(eq2e)
# Out:
# 5*y(x) - 4*diff(y(x), x) + diff(y(x), x, x) == 2*x^2*e^x

# %%
sol(x)=desolve(eq2e,y)
sol(x)
# Out:
# (_K2*cos(x) + _K1*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x

# %%
eq1=sol(0)==2
eq1
# Out:
# _K2 + 1 == 2

# %%
int1=diff(sol,x)
eq2=int1(0)==3
eq2
# Out:
# _K1 + 2*_K2 + 3 == 3

# %%
solve([eq1,eq2],_K1,_K2)
# Out:
# [[_K1 == -2, _K2 == 1]]

# %%
plot(sol(x).substitute(_K1==-2,_K2==1),x,-10,3,detect_poles='True',ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
pi
# Out:
# pi

# %%
show(pi)
# Out:
# pi

# %%
pi
# Out:
# pi

# %%
eq2f=diff(y,x,2)+4*y==4*(sin(2*x)+cos(2*x))
show(eq2f)
# Out:
# 4*y(x) + diff(y(x), x, x) == 4*cos(2*x) + 4*sin(2*x)

# %%
sol(x)=desolve(eq2f,y)
sol(x)
# Out:
# _K2*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + _K1*sin(2*x) + x*sin(2*x)

# %%
eq1=sol(pi)==2*pi

# %%
int1(x)=diff(sol(x),x)
eq2=int1(pi)==2*pi
eq1
# Out:
# -pi + _K2 + 1/2 == 2*pi

# %%
eq2
# Out:
# 2*pi + 2*_K1 - 1 == 2*pi

# %%
solve([eq1,eq2],_K1,_K2)
# Out:
# [[_K1 == (1/2), _K2 == 3*pi - 1/2]]

# %%
plot(sol(x).substitute(_K1 == (1/2), _K2 == 3*pi - 1/2),x,-3,3,detect_poles='True',ymin=-20,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
k=var('k')
_C=var('_C')
eq3=diff(y,x)+(k/x)*y==x^3
show(eq3)
# Out:
# k*y(x)/x + diff(y(x), x) == x^3

# %%
sol(x)=desolve(eq3,y,ivar=x)
sol(x)
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
plot(sol(x).substitute(k==1,_C==0),x,-5,5,detect_poles='True',ymin=0,ymax=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol(x).substitute(k==1,_C==2),x,-5,5,detect_poles='True',ymin=-10,ymax=20)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
eq=sol(1).substitute(k==1)==0
eq
# Out:
# _C + 1/5 == 0

# %%
solve(eq,_C)
# Out:
# [_C == (-1/5)]

# %%
plot(sol(x).substitute(k==1,_C==(-1/5)),x,-5,5,detect_poles='True',ymin=-5,ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
show(animate(plot(sol(x).substitute(_C==(-1/5))),x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6537)()
#     686         try:
# --> 687             ind = self._vars.index(var_name)
#     688         except ValueError:
#
# ValueError: 'x' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /private/var/tmp/sage-9.5-current/local/var/lib/sage/venv-python3.9.9/lib/python3.9/site-packages/sage/all_cmdline.py in <module>
# ----> 1 show(animate(plot(sol(x).substitute(_C==(-Integer(1)/Integer(5)))),x))
#
# ...

# %%
a=animate([sol(x),x,-5,5]\for k in range(0,14))
# Out:
#   File "/var/folders/1f/y65xdxcj2gqfny_fdgnvr4d80000gn/T/ipykernel_14070/2845372571.py", line 1
#     a=animate([sol(x),x,-Integer(5),Integer(5)] * BackslashOperator() * for k in range(Integer(0),Integer(14)))
#                                                                         ^
# SyntaxError: invalid syntax

# %%
reset()
x=var('x')
_C=var('_C')
a=var('a')
b=var('b')
_K1,_K2=var('_K1,_K2')
y=function('y')(x)
eqn=diff(y,x)==y+a*x+b
show(eqn)
# Out:
# diff(y(x), x) == a*x + b + y(x)

# %%
sol(x)=desolve(eqn,y,ivar=x)

# %%
solut(x,a,b)=solve(sol(x)==1,x)
show(solut(x,a,b))
# Out:
# (x == (_C*e^x - a - b - 1)/a)

# %%
solve([solut(1,a,b)[0].rhs()==-5+4*exp(1),solut(2,a,b)[0].rhs()==-7+4*exp(2)],a,b)
# Out:
# [[a == 1/2*_C*(e^2 - e)/(2*e^2 - 2*e - 1), b == (_C*(2*e^2 - 3*e) - 2*e^2 + 2*e + 1)/(2*e^2 - 2*e - 1)]]

# %%
solve(solut(0,1/2*_C*(e^2 - e)/(2*e^2 - 2*e - 1),_C*(2*e^2 - 3*e) - 2*e^2 + 2*e + 1)/(2*e^2 - 2*e - 1))[0].rhs()==1,C)
# Out:
#   File "/var/folders/1f/y65xdxcj2gqfny_fdgnvr4d80000gn/T/ipykernel_24841/945784985.py", line 1
#     solve(solut(Integer(0),Integer(1)/Integer(2)*_C*(e**Integer(2) - e)/(Integer(2)*e**Integer(2) - Integer(2)*e - Integer(1)),_C*(Integer(2)*e**Integer(2) - Integer(3)*e) - Integer(2)*e**Integer(2) + Integer(2)*e + Integer(1))/(Integer(2)*e**Integer(2) - Integer(2)*e - Integer(1)))[Integer(0)].rhs()==Integer(1),C)
#                                                                                                                                                                                                                                                                                                                            ^
# SyntaxError: unmatched ')'

# %%
eq=ph(a,b)==-5+4*exp(1)

# %%
# Out:
# False
